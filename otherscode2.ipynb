# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import re
import nltk
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import callbacks, models, layers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
# bag of words

# %%
train = pd.read_csv("data/labeledTrainData.tsv", header=0, delimiter="\t", quoting=3)
test = pd.read_csv("data/testData.tsv", header=0, delimiter="\t", quoting=3)

# Splitting the dataset into training and validation sets
split_size = int(len(train)*0.8)

training_reviews = train.review[:split_size]
training_sentiments = train.sentiment[:split_size]
validation_reviews = train.review[split_size:]
validation_sentiments = train.sentiment[split_size:]

# %%
# Text to Sequence and Padding
vocab_size = 10000
embedding_dim = 32
max_length = 200
trunc_type='post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(training_reviews)

training_sequences = tokenizer.texts_to_sequences(training_reviews)
padded_training = pad_sequences(training_sequences, maxlen=max_length)

validation_sequences = tokenizer.texts_to_sequences(validation_reviews)
padded_validation = pad_sequences(validation_sequences, maxlen=max_length)

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def __init__(self, accuracy=0.90):
        self.accuracy = accuracy
        
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy')>=self.accuracy):
            print(f"\nReached {self.accuracy} accuracy so cancelling training!")
            self.model.stop_training = True

# %%
# Building the Neural Network
model = tf.keras.models.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

callbacks = CustomCallback()

model.compile(loss='binary_crossentropy',
             optimizer=tf.optimizers.Adam(learning_rate=0.001),
             metrics=['accuracy'])

model.summary()

model.fit(padded_training, training_sentiments, epochs=50, callbacks=[callbacks], validation_data=(padded_validation, validation_sentiments))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 32)           320000
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                204832
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 524,865
# Trainable params: 524,865
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 4s 5ms/step - loss: 0.4085 - accuracy: 0.8004 - val_loss: 0.3016 - val_accuracy: 0.8686
# Epoch 2/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1121 - accuracy: 0.9630 - val_loss: 0.3598 - val_accuracy: 0.8570
# Epoch 3/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0142 - accuracy: 0.9981 - val_loss: 0.4330 - val_accuracy: 0.8614
# Epoch 4/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.4855 - val_accuracy: 0.8604
# Epoch 5/50
# 625/625 [==============================] - 3s 5ms/step - loss: 7.0015e-04 - accuracy: 1.0000 - val_loss: 0.5046 - val_accuracy: 0.8634
# Epoch 6/50
# 625/625 [==============================] - 3s 5ms/step - loss: 3.2282e-04 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.8644
# Epoch 7/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.9289e-04 - accuracy: 1.0000 - val_loss: 0.5505 - val_accuracy: 0.8662
# Epoch 8/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.2154e-04 - accuracy: 1.0000 - val_loss: 0.5721 - val_accuracy: 0.8650
# Epoch 9/50
# 625/625 [==============================] - 3s 4ms/step - loss: 7.9143e-05 - accuracy: 1.0000 - val_loss: 0.5919 - val_accuracy: 0.8646
# Epoch 10/50
# 625/625 [==============================] - 3s 5ms/step - loss: 5.2728e-05 - accuracy: 1.0000 - val_loss: 0.6125 - val_accuracy: 0.8660
# Epoch 11/50
# 625/625 [==============================] - 3s 4ms/step - loss: 3.5899e-05 - accuracy: 1.0000 - val_loss: 0.6296 - val_accuracy: 0.8646
# Epoch 12/50
# 625/625 [==============================] - 3s 5ms/step - loss: 2.4376e-05 - accuracy: 1.0000 - val_loss: 0.6492 - val_accuracy: 0.8638
# Epoch 13/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.6794e-05 - accuracy: 1.0000 - val_loss: 0.6664 - val_accuracy: 0.8642
# Epoch 14/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1634e-05 - accuracy: 1.0000 - val_loss: 0.6842 - val_accuracy: 0.8646
# Epoch 15/50
# 625/625 [==============================] - 3s 5ms/step - loss: 8.0904e-06 - accuracy: 1.0000 - val_loss: 0.7032 - val_accuracy: 0.8632
# Epoch 16/50
# 625/625 [==============================] - 3s 5ms/step - loss: 5.6143e-06 - accuracy: 1.0000 - val_loss: 0.7203 - val_accuracy: 0.8636
# Epoch 17/50
# 625/625 [==============================] - 3s 5ms/step - loss: 3.9218e-06 - accuracy: 1.0000 - val_loss: 0.7387 - val_accuracy: 0.8642
# Epoch 18/50
# 625/625 [==============================] - 3s 5ms/step - loss: 2.7686e-06 - accuracy: 1.0000 - val_loss: 0.7563 - val_accuracy: 0.8632
# Epoch 19/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.9367e-06 - accuracy: 1.0000 - val_loss: 0.7732 - val_accuracy: 0.8638
# Epoch 20/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.3747e-06 - accuracy: 1.0000 - val_loss: 0.7916 - val_accuracy: 0.8638
# Epoch 21/50
# 625/625 [==============================] - 3s 5ms/step - loss: 9.7209e-07 - accuracy: 1.0000 - val_loss: 0.8095 - val_accuracy: 0.8640
# Epoch 22/50
# 625/625 [==============================] - 3s 5ms/step - loss: 6.9015e-07 - accuracy: 1.0000 - val_loss: 0.8252 - val_accuracy: 0.8634
# Epoch 23/50
# 625/625 [==============================] - 3s 5ms/step - loss: 4.9254e-07 - accuracy: 1.0000 - val_loss: 0.8426 - val_accuracy: 0.8634
# Epoch 24/50
# 625/625 [==============================] - 3s 5ms/step - loss: 3.5234e-07 - accuracy: 1.0000 - val_loss: 0.8595 - val_accuracy: 0.8628
# Epoch 25/50
# 625/625 [==============================] - 3s 5ms/step - loss: 2.5312e-07 - accuracy: 1.0000 - val_loss: 0.8758 - val_accuracy: 0.8632
# Epoch 26/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.8330e-07 - accuracy: 1.0000 - val_loss: 0.8922 - val_accuracy: 0.8636
# Epoch 27/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.3323e-07 - accuracy: 1.0000 - val_loss: 0.9081 - val_accuracy: 0.8630
# Epoch 28/50
# 625/625 [==============================] - 3s 5ms/step - loss: 9.7993e-08 - accuracy: 1.0000 - val_loss: 0.9233 - val_accuracy: 0.8630
# Epoch 29/50
# 625/625 [==============================] - 4s 6ms/step - loss: 7.2323e-08 - accuracy: 1.0000 - val_loss: 0.9401 - val_accuracy: 0.8640
# Epoch 30/50
# 625/625 [==============================] - 2s 4ms/step - loss: 5.3901e-08 - accuracy: 1.0000 - val_loss: 0.9541 - val_accuracy: 0.8632
# Epoch 31/50
# 625/625 [==============================] - 3s 5ms/step - loss: 4.0411e-08 - accuracy: 1.0000 - val_loss: 0.9689 - val_accuracy: 0.8636
# Epoch 32/50
# 625/625 [==============================] - 2s 4ms/step - loss: 3.0418e-08 - accuracy: 1.0000 - val_loss: 0.9840 - val_accuracy: 0.8632
# Epoch 33/50
# 625/625 [==============================] - 3s 4ms/step - loss: 2.3280e-08 - accuracy: 1.0000 - val_loss: 0.9984 - val_accuracy: 0.8638
# Epoch 34/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.7986e-08 - accuracy: 1.0000 - val_loss: 1.0134 - val_accuracy: 0.8640
# Epoch 35/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.3857e-08 - accuracy: 1.0000 - val_loss: 1.0268 - val_accuracy: 0.8640
# Epoch 36/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.0909e-08 - accuracy: 1.0000 - val_loss: 1.0399 - val_accuracy: 0.8638
# Epoch 37/50
# 625/625 [==============================] - 3s 4ms/step - loss: 8.7308e-09 - accuracy: 1.0000 - val_loss: 1.0539 - val_accuracy: 0.8640
# Epoch 38/50
# 625/625 [==============================] - 3s 4ms/step - loss: 7.1520e-09 - accuracy: 1.0000 - val_loss: 1.0646 - val_accuracy: 0.8640
# Epoch 39/50
# 625/625 [==============================] - 3s 5ms/step - loss: 5.9878e-09 - accuracy: 1.0000 - val_loss: 1.0792 - val_accuracy: 0.8644
# Epoch 40/50
# 625/625 [==============================] - 3s 4ms/step - loss: 5.1703e-09 - accuracy: 1.0000 - val_loss: 1.0905 - val_accuracy: 0.8642
# Epoch 41/50
# 625/625 [==============================] - 3s 4ms/step - loss: 4.5395e-09 - accuracy: 1.0000 - val_loss: 1.0996 - val_accuracy: 0.8644
# Epoch 42/50
# 625/625 [==============================] - 3s 5ms/step - loss: 4.1534e-09 - accuracy: 1.0000 - val_loss: 1.1091 - val_accuracy: 0.8642
# Epoch 43/50
# 625/625 [==============================] - 3s 5ms/step - loss: 3.8143e-09 - accuracy: 1.0000 - val_loss: 1.1167 - val_accuracy: 0.8644
# Epoch 44/50
# 625/625 [==============================] - 3s 4ms/step - loss: 3.5480e-09 - accuracy: 1.0000 - val_loss: 1.1287 - val_accuracy: 0.8644
# Epoch 45/50
# 625/625 [==============================] - 3s 4ms/step - loss: 3.3585e-09 - accuracy: 1.0000 - val_loss: 1.1346 - val_accuracy: 0.8642
# Epoch 46/50
# 625/625 [==============================] - 3s 4ms/step - loss: 3.2202e-09 - accuracy: 1.0000 - val_loss: 1.1439 - val_accuracy: 0.8650
# Epoch 47/50
# 625/625 [==============================] - 3s 4ms/step - loss: 3.0719e-09 - accuracy: 1.0000 - val_loss: 1.1497 - val_accuracy: 0.8634
# Epoch 48/50
# 625/625 [==============================] - 3s 4ms/step - loss: 3.0204e-09 - accuracy: 1.0000 - val_loss: 1.1522 - val_accuracy: 0.8646
# Epoch 49/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0254 - accuracy: 0.9936 - val_loss: 1.0482 - val_accuracy: 0.8482
# Epoch 50/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0245 - accuracy: 0.9929 - val_loss: 0.9445 - val_accuracy: 0.8504

# %%
# Evaluating the neural network model
accuracy_score = model.evaluate(padded_validation, validation_sentiments, verbose=0)[1]
print(f"Accuracy Score: {round(accuracy_score*100, 2)}%")
# Out:
# Accuracy Score: 85.04%

# %%
# Making predictions on the test set
testing_sequences = tokenizer.texts_to_sequences(test.review)
padded_testing = pad_sequences(testing_sequences, maxlen=max_length)

sentiment_predictions = list(map(lambda sentiment: 1 if sentiment > 0.5 else 0, model.predict(padded_testing)))
pd.DataFrame({'Predictions':sentiment_predictions}).head(10)
# Out:
#    Predictions
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1
# 5            0
# 6            0
# 7            0
# 8            0
# 9            0

# %%
# Positive Review
print(f"Review:\n{test.review[0]}\n\nSentiment: {'Positive' if sentiment_predictions[0] == 1 else 'Negative'}")
# Out:
# Review:
# "Naturally in a film who's main themes are of mortality, nostalgia, and loss of innocence it is perhaps not surprising that it is rated more highly by older viewers than younger ones. However there is a craftsmanship and completeness to the film which anyone can enjoy. The pace is steady and constant, the characters full and engaging, the relationships and interactions natural showing that you do not need floods of tears to show emotion, screams to show fear, shouting to show dispute or violence to show anger. Naturally Joyce's short story lends the film a ready made structure as perfect as a polished diamond, but the small changes Huston makes such as the inclusion of the poem fit in neatly. It is truly a masterpiece of tact, subtlety and overwhelming beauty."
#
# Sentiment: Positive

# %%
# Submitting the results
output = pd.DataFrame(data={"id":test.id, 
                            "sentiment":sentiment_predictions})

output.to_csv("submission.csv", index=False, quoting=3)
